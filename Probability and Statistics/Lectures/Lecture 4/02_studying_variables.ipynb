# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# %%
import pandas as pd
url = "D:/Basics_for_Machine_Learning_and_AI/Probability and Statistics/data/nhanes_2015_2016.csv"
da = pd.read_csv(url)

# %% [markdown]
# # **Studing Discrete Values**

# %%
gender = da['RIAGENDR']
gender.value_counts()
# Out:
# 2    2976
# 1    2759
# Name: RIAGENDR, dtype: int64

# %%
gender.value_counts().plot(kind='bar')
plt.show()

# %%
gender.value_counts().plot(kind='bar')
plt.xticks([0, 1], ['Male', 'Female'])
plt.xlabel("Gender")
plt.ylabel("Frequency")
plt.show()

# %%
sizes = np.array([22, 23, 29, 32, 39, 42, 42, 42, 42, 42, 42, 42, 42, 43, 44, 46, 51, 51, 55, 55, 57, 58, 78, 83, 97, 97])

# %%
sizes.mean()
# Out:
# 49.84615384615385

# %%
from collections import Counter
cnt = Counter()

for size in sizes:
    cnt[size] += 1
    
cnt.most_common()           # index 0 is the most common i.e. the node
# Out:
# [(42, 8),
#  (51, 2),
#  (55, 2),
#  (97, 2),
#  (22, 1),
#  (23, 1),
#  (29, 1),
#  (32, 1),
#  (39, 1),
#  (43, 1),
#  (44, 1),
#  (46, 1),
#  (57, 1),
#  (58, 1),
#  (78, 1),
#  (83, 1)]

# %% [markdown]
# Alternative method: use the scipy library

# %%
# !pip install scipy

# %%
from scipy import stats
stats.mode(sizes)           # index 0 has value, index 1 has count
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_14864\491580280.py:2: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   stats.mode(sizes)           # index 0 has value, index 1 has count
# ModeResult(mode=array([42]), count=array([8]))

# %%
gender.mode()               # not too useful since we could have got that from the bar chart anyway
# Out:
# 0    2
# Name: RIAGENDR, dtype: int64

# %%
stats.mode(gender)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\611529493.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   stats.mode(gender)
# ModeResult(mode=array([2], dtype=int64), count=array([2976]))

# %% [markdown]
# # More than One "Classes"

# %%
da['HIQ210'].unique()
# Out:
# array([ 2., nan,  1.,  9.])

# %%
da['HIQ210'].value_counts().plot(kind='bar')
plt.show()

# %%
da['HIQ210'].value_counts().plot(kind= 'pie')        # highly NOT recommended!
plt.show()

# %% [markdown]
# # Studing Real-Valued Numbers

# %%
wt = da['BMXWT']

# %%
wt.value_counts().plot(kind='bar')      # this does not work at all
plt.show()

# %%
wt.hist(bins = 2)       # in bins atribute we say that divide the data into 2 parts irrespect of the different frequency and plot them
plt.show()

# %% [markdown]
# # **Custom Matplotlib Histogram**

# %%
plt.hist(wt, bins=30)
plt.ylabel('Frequency')
plt.xlabel('Weights')
plt.title("Histogram of weights in NHANES Dataset")
plt.show()

# %% [markdown]
# **Prettifing and styling Matplotlib with Seaborn**

# %%
# !pip install seaborn

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.set_style("white")             # See more styling options on website:  https://seaborn.pydata.org/tutorial/aesthetics.html

# %%
sns.displot(wt, bins =20)       # try ,kde=True         # to get rid of the "trend line"
plt.ylabel('Frequency')
plt.xlabel('Weights')
plt.title("Historgram of weights in NHANES Dataset")
sns.despine(offset=5, trim=True)      # move extra or unused axes away
plt.show()

# %% [markdown]
# See many more options about histograms with seaborn here: https://seaborn.pydata.org/tutorial/distributions.html

# %% [markdown]
# # **Study Central Tendency**

# %%
plt.figure(figsize=(20, 5))

x = range(da['BMXWT'].size)
y = da['BMXWT']

plt.scatter(x, y, marker='x', s = 0.5)

plt.title("Weights of Indiviuals")
plt.xlabel("ID of Individual")
plt.ylabel("Weight (kg)")

p1 = (0,75)
p2 = (6000, 75)
x_c, y_c = zip(p1, p2)
plt.plot(x_c, y_c, color = 'red', linewidth = 0.75)
plt.show()

# %%
wt.mean()
# Out:
# 81.34267560889516

# %%
plt.figure(figsize=(20, 5))

x = range(da['BMXWT'].size)
y = da['BMXWT']

plt.scatter(x, y, marker='x', s = 0.5)

plt.title("Weights of Indiviuals")
plt.xlabel("ID of Individual")
plt.ylabel("Weight (kg)")

# plot the estimate line
x_c, y_c = ([0, 6000] , [75, 75])
plt.plot(x_c, y_c, color = 'red', linewidth = 0.75)


# plot the line according to mean
x_c, y_c = ([0, 6000] , [wt.mean(), wt.mean()])
plt.plot(x_c, y_c, color = 'green', linewidth = 2)


plt.show()

# %%
import numpy as np

# %%
nums = np.array([3, 4, 9, 17, 18, 20, 22, 23, 29, 32, 39, 42, 42,42, 51, 197])      # try without 197

# %%
np.mean(nums)
# Out:
# 36.875

# %%
# let's try to do a different kind of average: the median!
np.median(nums)
# Out:
# 26.0

# %% [markdown]
# # **Visuslizing Weights Data**
#
# The problem with our weights data is similar.

# %%
wt.max()
# Out:
# 198.9

# %%
wt.min()
# Out:
# 32.4

# %%
wt.median()
# Out:
# 78.2

# %%
plt.figure(figsize=(20, 5))

x = range(da['BMXWT'].size)
y = da['BMXWT']

plt.scatter(x, y, marker='x', s = 0.5)

plt.title("Weights of Indiviuals")
plt.xlabel("ID of Individual")
plt.ylabel("Weight (kg)")

# plot the line of median 
x_c, y_c = ([0, 6000] , [wt.median(), wt.median()])
plt.plot(x_c, y_c, color = 'red', linewidth = 0.75)


# plot the line of mean
x_c, y_c = ([0, 6000] , [wt.mean(), wt.mean()])
plt.plot(x_c, y_c, color = 'green', linewidth = 2)


plt.show()

# %%
nums = np.array([3, 4, 9, 17, 18, 20, 22, 23, 29, 32, 39, 42, 42,42, 51, 97])

# %%
np.median(nums)
# Out:
# 26.0

# %%
import statistics

# %%
statistics.quantiles(nums, n = 4)
# Out:
# [17.25, 26.0, 42.0]

# %%
statistics.quantiles(wt, n = 4)
# Out:
# [43.7, 52.5, 50.1]

# %%
ax = sns.boxplot(x = wt)

# %%
# consider it as an SQL quaries
# from da select da['BMWXT'] where da['RIAGENDR] == 2

# here we are getting weight of mens
male_wt = da.loc[da['RIAGENDR'] == 2, 'BMXWT']

# male_wt.mean()   
male_wt                # try  .mean()
# Out:
# 3       109.8
# 4        55.2
# 5        64.4
# 7        64.5
# 12       71.2
#         ...
# 5724     58.2
# 5727     64.8
# 5730     59.1
# 5732     71.7
# 5734     58.3
# Name: BMXWT, Length: 2976, dtype: float64

# %%
# here we are getting weight of womens
female_wt = da.loc[da['RIAGENDR'] == 1, 'BMXWT']
# female_wt.mean()
female_wt
# Out:
# 0        94.8
# 1        90.4
# 2        83.4
# 6        76.6
# 8        72.4
#         ...
# 5726     78.7
# 5728     89.5
# 5729     39.2
# 5731    112.1
# 5733     78.2
# Name: BMXWT, Length: 2759, dtype: float64

# %%
# But there's an easier way
plt.figure(figsize=(4, 8))
sns.set_style("whitegrid")

ax = sns.boxplot(x = "RIAGENDR", y = "BMXWT",  data = da,  palette="Set3")   # from table(data) = da
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\1240205391.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x = "RIAGENDR", y = "BMXWT",  data = da,  palette="Set3")   # from table(data) = da

# %%
# But there's an easier way
plt.figure(figsize=(4, 8))
sns.set_style("whitegrid")

ax = sns.boxplot(x = "HIQ210", y = "BMXWT",  data = da,  palette="Set3")
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17024\3035110002.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x = "HIQ210", y = "BMXWT",  data = da,  palette="Set3")
